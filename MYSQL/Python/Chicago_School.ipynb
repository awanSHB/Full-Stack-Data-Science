# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("default")
import csv, sqlite3

# %%
conn = sqlite3.connect("RealWorldData.db")
cur = conn.cursor()

# %%
# %load_ext sql 
# %sql sqlite:///RealWorldData.db

# %%
df = pd.read_csv("D:\PROGRAMMING\DATASETS\ChicagoPublicSchools.csv")
print(df.shape)
df.head()
# Out:
# (566, 78)
#    School_ID                                     NAME_OF_SCHOOL
# 0     610038                  Abraham Lincoln Elementary School  \
# 1     610281  Adam Clayton Powell Paideia Community Academy ...
# 2     610185                Adlai E Stevenson Elementary School
# 3     609993                    Agustin Lara Elementary Academy
# 4     610513                      Air Force Academy High School
#
#   Elementary, Middle, or High School         Street_Address     City State
# 0                                 ES        615 W Kemper Pl  Chicago    IL  \
# 1                                 ES  7511 S South Shore Dr  Chicago    IL
# 2                                 ES     8010 S Kostner Ave  Chicago    IL
# 3                                 ES     4619 S Wolcott Ave  Chicago    IL
# 4                                 HS        3630 S Wells St  Chicago    IL
#
#    ZIP_Code    Phone_Number
# 0     60614  (773) 534-5720  \
# 1     60649  (773) 535-6650
# ...

# %%
chunksize = 100  # You can adjust this based on your data size
for i in range(0, len(df), chunksize):
    df.iloc[i:i+chunksize].to_sql("Chicago_School_Data", conn, if_exists='append', index=False)

# %%
# %sql SELECT * FROM Chicago_School_Data LIMIT 10;
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [(610038, 'Abraham Lincoln Elementary School', 'ES', '615 W Kemper Pl', 'Chicago', 'IL', 60614, '(773) 534-5720', 'http://schoolreports.cps.edu/SchoolProgressReport_Eng/Spring2011Eng_610038.pdf', 'Fullerton Elementary Network', 'NORTH-NORTHWEST SIDE COLLABORATIVE', 'No', 'Standard', 'Not on Probation', 'Level 1', 'Yes', 'Very Strong', 99.0, 'Very Strong', '99', 'Strong', 74.0, 'Strong', 66.0, 'Weak', '65', 'Strong', '70', 'Strong', '56', 'Average', '47', '96.00%', 2.0, '96.40%', '95.80%', '80.1', '43.3', '89.6', '84.9', '60.7', '62.6', '81.9', '85.2', '52', '62.4', '66.3', '77.9', 69.7, 64.4, 0.2, 0.9, 'Yellow', 'Green', '67.1', '54.5', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 813, 33, 'NDA', 1171699.458, 1915829.428, 41.92449696, -87.64452163, 7, 'LINCOLN PARK', 43, 18, '(41.92449696, -87.64452163)'),
# ...

# %%
# %sql SELECT COUNT(*) as "Total_rows" FROM Chicago_School_Data;
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [(566,)]

# %% [markdown]
# * count the total columns

# %%
# %sql SELECT COUNT(*) as "Total_Columns" FROM pragma_table_info('Chicago_School_Data');
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [(78,)]

# %% [markdown]
# * retrieve the column `name`, `datatype` and `type length`

# %%
# %sql SELECT name, type, length(type) FROM pragma_table_info('Chicago_School_Data');
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('School_ID', 'INTEGER', 7),
#  ('NAME_OF_SCHOOL', 'TEXT', 4),
#  ('Elementary, Middle, or High School', 'TEXT', 4),
#  ('Street_Address', 'TEXT', 4),
#  ('City', 'TEXT', 4),
#  ('State', 'TEXT', 4),
#  ('ZIP_Code', 'INTEGER', 7),
#  ('Phone_Number', 'TEXT', 4),
#  ('Link', 'TEXT', 4),
#  ('Network_Manager', 'TEXT', 4),
#  ('Collaborative_Name', 'TEXT', 4),
#  ('Adequate_Yearly_Progress_Made_', 'TEXT', 4),
#  ('Track_Schedule', 'TEXT', 4),
#  ('CPS_Performance_Policy_Status', 'TEXT', 4),
#  ('CPS_Performance_Policy_Level', 'TEXT', 4),
#  ('HEALTHY_SCHOOL_CERTIFIED', 'TEXT', 4),
#  ('Safety_Icon', 'TEXT', 4),
#  ('SAFETY_SCORE', 'REAL', 4),
#  ('Family_Involvement_Icon', 'TEXT', 4),
#  ('Family_Involvement_Score', 'TEXT', 4),
#  ('Environment_Icon', 'TEXT', 4),
#  ('Environment_Score', 'REAL', 4),
#  ('Instruction_Icon', 'TEXT', 4),
#  ('Instruction_Score', 'REAL', 4),
#  ('Leaders_Icon', 'TEXT', 4),
#  ('Leaders_Score', 'TEXT', 4),
# ...

# %%
# %sql SELECT name, type, length(type) FROM pragma_table_info('Chicago_School_Data') \
WHERE type = 'INTEGER';
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('School_ID', 'INTEGER', 7),
#  ('ZIP_Code', 'INTEGER', 7),
#  ('COLLEGE_ENROLLMENT', 'INTEGER', 7),
#  ('General_Services_Route', 'INTEGER', 7),
#  ('COMMUNITY_AREA_NUMBER', 'INTEGER', 7),
#  ('Ward', 'INTEGER', 7),
#  ('Police_District', 'INTEGER', 7)]

# %%
# %sql SELECT DISTINCT type FROM pragma_table_info('Chicago_School_Data');
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('INTEGER',), ('TEXT',), ('REAL',)]

# %%
# %sql SELECT * FROM Chicago_School_Data LIMIT 5;
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [(610038, 'Abraham Lincoln Elementary School', 'ES', '615 W Kemper Pl', 'Chicago', 'IL', 60614, '(773) 534-5720', 'http://schoolreports.cps.edu/SchoolProgressReport_Eng/Spring2011Eng_610038.pdf', 'Fullerton Elementary Network', 'NORTH-NORTHWEST SIDE COLLABORATIVE', 'No', 'Standard', 'Not on Probation', 'Level 1', 'Yes', 'Very Strong', 99.0, 'Very Strong', '99', 'Strong', 74.0, 'Strong', 66.0, 'Weak', '65', 'Strong', '70', 'Strong', '56', 'Average', '47', '96.00%', 2.0, '96.40%', '95.80%', '80.1', '43.3', '89.6', '84.9', '60.7', '62.6', '81.9', '85.2', '52', '62.4', '66.3', '77.9', 69.7, 64.4, 0.2, 0.9, 'Yellow', 'Green', '67.1', '54.5', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 813, 33, 'NDA', 1171699.458, 1915829.428, 41.92449696, -87.64452163, 7, 'LINCOLN PARK', 43, 18, '(41.92449696, -87.64452163)'),
# ...

# %% [markdown]
# * How many `Elementary Schools` are these in the dataset?

# %%
# %%sql
# SELECT COUNT(*) as "Total_Elementary_Schools"
# FROM Chicago_School_Data
# WHERE "Elementary, Middle, or High School" = 'ES';
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [(462,)]

# %% [markdown]
# * Counting the `Frequency` of Schools

# %%
# %%sql
#
# SELECT "Elementary, Middle, or High School" as "School_Names", COUNT(*) as "Frequency"
# FROM Chicago_School_Data
# GROUP BY "Elementary, Middle, or High School"
# ORDER BY Frequency;
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('MS', 11), ('HS', 93), ('ES', 462)]

# %%
# %sql SELECT MAX("safety_score") FROM Chicago_School_Data;
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [(99.0,)]

# %%
# %sql SELECT "name_of_school", MAX("safety_score") FROM Chicago_School_Data;
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('Abraham Lincoln Elementary School', 99.0)]

# %% [markdown]
# * What are `Top 10` schools with `highest` Average Student Attendance?

# %%
# %%sql
# SELECT "name_of_school", "average_student_attendance"
# from Chicago_School_Data
# ORDER BY "average_student_attendance" DESC
# LIMIT 10;
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('John Charles Haines Elementary School', '98.40%'),
#  ('James Ward Elementary School', '97.80%'),
#  ('Edgar Allan Poe Elementary Classical School', '97.60%'),
#  ('Orozco Fine Arts & Sciences Elementary School', '97.60%'),
#  ('Rachel Carson Elementary School', '97.60%'),
#  ('Annie Keller Elementary Gifted Magnet School', '97.50%'),
#  ('Andrew Jackson Elementary Language Academy', '97.40%'),
#  ('Lenart Elementary Regional Gifted Center', '97.40%'),
#  ('Disney II Magnet School', '97.30%'),
#  ('John H Vanderpoel Elementary Magnet School', '97.20%')]

# %% [markdown]
# * What are `Top 10` schools with `lowest` Average Student Attendance?

# %%
# %%sql
# SELECT "name_of_school" as "School", "average_student_attendance" as "average_attendance"
# FROM Chicago_School_Data
# ORDER BY "average_attendance"
# LIMIT 10;
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('Velma F Thomas Early Childhood Center', None),
#  ('Richard T Crane Technical Preparatory High School', '57.90%'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90%'),
#  ('Dyett High School', '62.50%'),
#  ('Wendell Phillips Academy High School', '63.00%'),
#  ('Orr Academy High School', '66.30%'),
#  ('Manley Career Academy High School', '66.80%'),
#  ('Chicago Vocational Career Academy High School', '68.80%'),
#  ('Roberto Clemente Community Academy High School', '69.60%'),
#  ('Austin Polytechnical Academy High School', '70.10%')]

# %%
# %%sql
#
# SELECT "name_of_school" as "School", REPLACE("average_student_attendance", '%', '') as "average_attendance"
# FROM Chicago_School_Data
# ORDER BY "average_attendance"
# LIMIT 10;
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('Velma F Thomas Early Childhood Center', None),
#  ('Richard T Crane Technical Preparatory High School', '57.90'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90'),
#  ('Dyett High School', '62.50'),
#  ('Wendell Phillips Academy High School', '63.00'),
#  ('Orr Academy High School', '66.30'),
#  ('Manley Career Academy High School', '66.80'),
#  ('Chicago Vocational Career Academy High School', '68.80'),
#  ('Roberto Clemente Community Academy High School', '69.60'),
#  ('Austin Polytechnical Academy High School', '70.10')]

# %%
# %%sql
#
# SELECT "name_of_school" as "School", "average_student_attendance" as "average_attendance"
# FROM Chicago_School_Data
# WHERE "average_student_attendance" <= 70;
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('Barbara Vick Early Childhood & Family Center', '60.90%'),
#  ('Chicago Vocational Career Academy High School', '68.80%'),
#  ('Dyett High School', '62.50%'),
#  ('Manley Career Academy High School', '66.80%'),
#  ('Orr Academy High School', '66.30%'),
#  ('Richard T Crane Technical Preparatory High School', '57.90%'),
#  ('Roberto Clemente Community Academy High School', '69.60%'),
#  ('Wendell Phillips Academy High School', '63.00%')]

# %%
# %sql SELECT * FROM Chicago_School_Data LIMIT 10;
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [(610038, 'Abraham Lincoln Elementary School', 'ES', '615 W Kemper Pl', 'Chicago', 'IL', 60614, '(773) 534-5720', 'http://schoolreports.cps.edu/SchoolProgressReport_Eng/Spring2011Eng_610038.pdf', 'Fullerton Elementary Network', 'NORTH-NORTHWEST SIDE COLLABORATIVE', 'No', 'Standard', 'Not on Probation', 'Level 1', 'Yes', 'Very Strong', 99.0, 'Very Strong', '99', 'Strong', 74.0, 'Strong', 66.0, 'Weak', '65', 'Strong', '70', 'Strong', '56', 'Average', '47', '96.00%', 2.0, '96.40%', '95.80%', '80.1', '43.3', '89.6', '84.9', '60.7', '62.6', '81.9', '85.2', '52', '62.4', '66.3', '77.9', 69.7, 64.4, 0.2, 0.9, 'Yellow', 'Green', '67.1', '54.5', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 813, 33, 'NDA', 1171699.458, 1915829.428, 41.92449696, -87.64452163, 7, 'LINCOLN PARK', 43, 18, '(41.92449696, -87.64452163)'),
# ...

# %% [markdown]
# * Total college enrollment for each community area

# %%
# %%sql
#
# SELECT "community_area_name" , SUM("college_enrollment") as "total_college_enrollment"
# FROM Chicago_school_Data
# GROUP BY "community_area_name"
# ORDER BY "total_college_enrollment";
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('OAKLAND', 140),
#  ('FULLER PARK', 531),
#  ('BURNSIDE', 549),
#  ('OHARE', 786),
#  ('LOOP', 871),
#  ('EDISON PARK', 910),
#  ('HEGEWISCH', 963),
#  ('MONTCLARE', 1317),
#  ('NEAR SOUTH SIDE', 1378),
#  ('FOREST GLEN', 1431),
#  ('ARMOUR SQUARE', 1458),
#  ('AVALON PARK', 1522),
#  ('RIVERDALE', 1547),
#  ('MCKINLEY PARK', 1552),
#  ('CALUMET HEIGHTS', 1568),
#  ('PULLMAN', 1620),
#  ('BEVERLY', 1636),
#  ('JEFFERSON PARK', 1755),
#  ('SOUTH DEERING', 1859),
#  ('HYDE PARK', 1930),
#  ('CLEARING', 2085),
#  ('MOUNT GREENWOOD', 2091),
#  ('WEST GARFIELD PARK', 2622),
#  ('WASHINGTON PARK', 2648),
#  ('GRAND BOULEVARD', 2809),
#  ('BRIDGEPORT', 3167),
#  ('WEST PULLMAN', 3240),
#  ('MORGAN PARK', 3271),
#  ('NEAR NORTH SIDE', 3362),
#  ('AVONDALE', 3640),
#  ('WEST ELSDON', 3700),
#  ('HERMOSA', 3975),
#  ('WASHINGTON HEIGHTS', 4006),
#  ('SOUTH CHICAGO', 4043),
#  ('GREATER GRAND CROSSING', 4051),
#  ('ROGERS PARK', 4068),
# ...

# %%
# %%sql
#
# SELECT "community_area_name" , SUM("college_enrollment") as "total_college_enrollment"
# FROM Chicago_school_Data
# GROUP BY "community_area_name"
# ORDER BY "total_college_enrollment"
# LIMIT 5;
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('OAKLAND', 140),
#  ('FULLER PARK', 531),
#  ('BURNSIDE', 549),
#  ('OHARE', 786),
#  ('LOOP', 871)]

# %% [markdown]
# * Schools with lowest safety score

# %%
# %%sql
#
# SELECT "name_of_school", "safety_score"
# FROM Chicago_School_Data
# WHERE "safety_score" != 'None'
# ORDER BY "safety_score"
# LIMIT 5;
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('Edmond Burke Elementary School', 1.0),
#  ("Luke O'Toole Elementary School", 5.0),
#  ('George W Tilton Elementary School', 6.0),
#  ('Foster Park Elementary School', 11.0),
#  ('Emil G Hirsch Metropolitan High School', 13.0)]

# %%
conn.close()
